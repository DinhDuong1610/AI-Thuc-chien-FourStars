# %%
import json, os, datetime, textwrap

base = "/mnt/data/ai-thuc-chien"
os.makedirs(base + "/outputs/raw", exist_ok=True)
os.makedirs(base + "/outputs/final", exist_ok=True)
os.makedirs(base + "/prompts", exist_ok=True)

# %%
def nb(cells, title="AI Thực Chiến – Template All-in-One"):
    return {
        "cells": cells,
        "metadata": {
            "kernelspec": {"display_name": "Python 3", "language": "python", "name": "python3"},
            "language_info": {"name": "python", "version": "3.x"}
        },
        "nbformat": 4,
        "nbformat_minor": 5
    }

def md(s): return {"cell_type":"markdown","metadata":{}, "source": s}
def code(s): return {"cell_type":"code","metadata":{}, "execution_count": None, "outputs": [], "source": s}

now = datetime.datetime.now().strftime("%Y-%m-%d %H:%M")

cells = []
